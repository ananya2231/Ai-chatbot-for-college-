# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import re

# Load the dataset from the uploaded file
try:
    df = pd.read_csv('symbiosis_mba_unique_faq.csv')
    print("Dataset loaded successfully!")
except FileNotFoundError:
    print("Error: 'symbiosis_mba_unique_faq.csv' not found.")
    print("Please make sure the file is in the same directory as your Jupyter notebook.")
    df = None

if df is not None:
    # --- 1. Text Preprocessing ---
    def preprocess_text(text):
        """
        This function cleans up the text by:
        1. Converting it to lowercase.
        2. Removing punctuation.
        """
        text = text.lower()
        text = re.sub(r'[^\w\s]', '', text)
        return text

    # Apply the preprocessing to all questions in your dataset
    df['Processed_Question'] = df['Question'].apply(preprocess_text)

    # --- 2. TF-IDF Vectorization ---
    # Create a TF-IDF Vectorizer to convert text to numerical data
    vectorizer = TfidfVectorizer()

    # Fit and transform the processed questions
    question_vectors = vectorizer.fit_transform(df['Processed_Question'])


    # --- 3. Chatbot Response Function ---
    def get_response(user_input):
        """
        This function finds the most relevant answer from the dataset
        for a given user question.
        """
        # Preprocess the user's input question
        processed_user_input = preprocess_text(user_input)

        # Convert the user's question into a vector
        user_vector = vectorizer.transform([processed_user_input])

        # Calculate the cosine similarity between the user's question and all dataset questions
        similarities = cosine_similarity(user_vector, question_vectors)

        # Find the index of the most similar question
        most_similar_index = similarities.argmax()

        # Retrieve the corresponding answer
        answer = df['Answer'].iloc[most_similar_index]

        return answer

    # --- 4. Running the Chatbot ---
    print("\nChatbot is ready! Type 'quit' to exit.")

    while True:
        user_question = input("You: ")
        if user_question.lower() == 'quit':
            break
        response = get_response(user_question)
        print(f"Bot: {response}")
# Out:
# Dataset loaded successfully!
#
# Chatbot is ready! Type 'quit' to exit.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 65
#      62 print("\nChatbot is ready! Type 'quit' to exit.")
#      64 while True:
# ---> 65     user_question = input("You: ")
#      66     if user_question.lower() == 'quit':
#      67         break
#
# File ~\anaconda3\Lib\site-packages\ipykernel\kernelbase.py:1282, in Kernel.raw_input(self, prompt)
#    1280     msg = "raw_input was called, but this frontend does not support input requests."
#    1281     raise StdinNotImplementedError(msg)
# -> 1282 return self._input_request(
#    1283     str(prompt),
#    1284     self._parent_ident["shell"],
#    1285     self.get_parent("shell"),
#    1286     password=False,
#    1287 )
#
# File ~\anaconda3\Lib\site-packages\ipykernel\kernelbase.py:1325, in Kernel._input_request(self, prompt, ident, parent, password)
#    1322 except KeyboardInterrupt:
#    1323     # re-raise KeyboardInterrupt, to truncate traceback
#    1324     msg = "Interrupted by user"
# -> 1325     raise KeyboardInterrupt(msg) from None
#    1326 except Exception:
#    1327     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
# !pip install gradio
# Out:
# Collecting gradio
#   Downloading gradio-5.46.1-py3-none-any.whl.metadata (16 kB)
# Collecting aiofiles<25.0,>=22.0 (from gradio)
#   Downloading aiofiles-24.1.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: anyio<5.0,>=3.0 in c:\users\ananya goel\anaconda3\lib\site-packages (from gradio) (4.7.0)
# Collecting audioop-lts<1.0 (from gradio)
#   Downloading audioop_lts-0.2.2-cp313-abi3-win_amd64.whl.metadata (2.0 kB)
# Collecting brotli>=1.1.0 (from gradio)
#   Downloading Brotli-1.1.0-cp313-cp313-win_amd64.whl.metadata (5.6 kB)
# Collecting fastapi<1.0,>=0.115.2 (from gradio)
#   Downloading fastapi-0.117.1-py3-none-any.whl.metadata (28 kB)
# Collecting ffmpy (from gradio)
#   Downloading ffmpy-0.6.1-py3-none-any.whl.metadata (2.9 kB)
# Collecting gradio-client==1.13.1 (from gradio)
#   Downloading gradio_client-1.13.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting groovy~=0.1 (from gradio)
#   Downloading groovy-0.1.2-py3-none-any.whl.metadata (6.1 kB)
# Requirement already satisfied: httpx<1.0,>=0.24.1 in c:\users\ananya goel\anaconda3\lib\site-packages (from gradio) (0.28.1)
# Collecting huggingface-hub<1.0,>=0.33.5 (from gradio)
#   Downloading huggingface_hub-0.35.0-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: jinja2<4.0 in c:\users\ananya goel\anaconda3\lib\site-packages (from gradio) (3.1.6)
# Requirement already satisfied: markupsafe<4.0,>=2.0 in c:\users\ananya goel\anaconda3\lib\site-packages (from gradio) (3.0.2)
# Requirement already satisfied: numpy<3.0,>=1.0 in c:\users\ananya goel\anaconda3\lib\site-packages (from gradio) (2.1.3)
# Collecting orjson~=3.0 (from gradio)
#   Downloading orjson-3.11.3-cp313-cp313-win_amd64.whl.metadata (43 kB)
# Requirement already satisfied: packaging in c:\users\ananya goel\anaconda3\lib\site-packages (from gradio) (24.2)
# Requirement already satisfied: pandas<3.0,>=1.0 in c:\users\ananya goel\anaconda3\lib\site-packages (from gradio) (2.2.3)
# Requirement already satisfied: pillow<12.0,>=8.0 in c:\users\ananya goel\anaconda3\lib\site-packages (from gradio) (11.1.0)
# Requirement already satisfied: pydantic<2.12,>=2.0 in c:\users\ananya goel\anaconda3\lib\site-packages (from gradio) (2.10.3)
# Collecting pydub (from gradio)
#   Downloading pydub-0.25.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting python-multipart>=0.0.18 (from gradio)
#   Downloading python_multipart-0.0.20-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in c:\users\ananya goel\anaconda3\lib\site-packages (from gradio) (6.0.2)
# Collecting ruff>=0.9.3 (from gradio)
#   Downloading ruff-0.13.1-py3-none-win_amd64.whl.metadata (26 kB)
# Collecting safehttpx<0.2.0,>=0.1.6 (from gradio)
#   Downloading safehttpx-0.1.6-py3-none-any.whl.metadata (4.2 kB)
# Collecting semantic-version~=2.0 (from gradio)
#   Downloading semantic_version-2.10.0-py2.py3-none-any.whl.metadata (9.7 kB)
# Collecting starlette<1.0,>=0.40.0 (from gradio)
#   Downloading starlette-0.48.0-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: tomlkit<0.14.0,>=0.12.0 in c:\users\ananya goel\anaconda3\lib\site-packages (from gradio) (0.13.2)
# Collecting typer<1.0,>=0.12 (from gradio)
#   Downloading typer-0.19.1-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: typing-extensions~=4.0 in c:\users\ananya goel\anaconda3\lib\site-packages (from gradio) (4.14.1)
# Collecting uvicorn>=0.14.0 (from gradio)
#   Downloading uvicorn-0.36.0-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: fsspec in c:\users\ananya goel\anaconda3\lib\site-packages (from gradio-client==1.13.1->gradio) (2025.3.2)
# Collecting websockets<16.0,>=10.0 (from gradio-client==1.13.1->gradio)
#   Downloading websockets-15.0.1-cp313-cp313-win_amd64.whl.metadata (7.0 kB)
# Requirement already satisfied: idna>=2.8 in c:\users\ananya goel\anaconda3\lib\site-packages (from anyio<5.0,>=3.0->gradio) (3.7)
# Requirement already satisfied: sniffio>=1.1 in c:\users\ananya goel\anaconda3\lib\site-packages (from anyio<5.0,>=3.0->gradio) (1.3.0)
# Requirement already satisfied: certifi in c:\users\ananya goel\anaconda3\lib\site-packages (from httpx<1.0,>=0.24.1->gradio) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in c:\users\ananya goel\anaconda3\lib\site-packages (from httpx<1.0,>=0.24.1->gradio) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\ananya goel\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1.0,>=0.24.1->gradio) (0.16.0)
# Requirement already satisfied: filelock in c:\users\ananya goel\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.33.5->gradio) (3.17.0)
# Requirement already satisfied: requests in c:\users\ananya goel\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.33.5->gradio) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\ananya goel\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.33.5->gradio) (4.67.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\ananya goel\anaconda3\lib\site-packages (from pandas<3.0,>=1.0->gradio) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ananya goel\anaconda3\lib\site-packages (from pandas<3.0,>=1.0->gradio) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\ananya goel\anaconda3\lib\site-packages (from pandas<3.0,>=1.0->gradio) (2025.2)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\ananya goel\anaconda3\lib\site-packages (from pydantic<2.12,>=2.0->gradio) (0.6.0)
# Requirement already satisfied: pydantic-core==2.27.1 in c:\users\ananya goel\anaconda3\lib\site-packages (from pydantic<2.12,>=2.0->gradio) (2.27.1)
# Requirement already satisfied: click>=8.0.0 in c:\users\ananya goel\anaconda3\lib\site-packages (from typer<1.0,>=0.12->gradio) (8.1.8)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\ananya goel\anaconda3\lib\site-packages (from typer<1.0,>=0.12->gradio) (1.5.0)
# Requirement already satisfied: rich>=10.11.0 in c:\users\ananya goel\anaconda3\lib\site-packages (from typer<1.0,>=0.12->gradio) (13.9.4)
# Requirement already satisfied: colorama in c:\users\ananya goel\anaconda3\lib\site-packages (from click>=8.0.0->typer<1.0,>=0.12->gradio) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\ananya goel\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas<3.0,>=1.0->gradio) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\ananya goel\anaconda3\lib\site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\ananya goel\anaconda3\lib\site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\ananya goel\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio) (0.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\ananya goel\anaconda3\lib\site-packages (from requests->huggingface-hub<1.0,>=0.33.5->gradio) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ananya goel\anaconda3\lib\site-packages (from requests->huggingface-hub<1.0,>=0.33.5->gradio) (2.5.0)
# Downloading gradio-5.46.1-py3-none-any.whl (60.4 MB)
#    ---------------------------------------- 0.0/60.4 MB ? eta -:--:--
#    --- ------------------------------------ 5.0/60.4 MB 26.9 MB/s eta 0:00:03
#    ------- -------------------------------- 10.7/60.4 MB 27.3 MB/s eta 0:00:02
#    ---------- ----------------------------- 16.3/60.4 MB 27.0 MB/s eta 0:00:02
#    -------------- ------------------------- 21.8/60.4 MB 27.4 MB/s eta 0:00:02
#    ------------------ --------------------- 28.0/60.4 MB 27.6 MB/s eta 0:00:02
#    -------------------- ------------------- 31.5/60.4 MB 25.6 MB/s eta 0:00:02
#    ----------------------- ---------------- 35.4/60.4 MB 24.7 MB/s eta 0:00:02
#    ------------------------- -------------- 39.1/60.4 MB 23.8 MB/s eta 0:00:01
#    ---------------------------- ----------- 43.0/60.4 MB 23.2 MB/s eta 0:00:01
#    ------------------------------- -------- 47.2/60.4 MB 22.7 MB/s eta 0:00:01
#    ----------------------------------- ---- 53.5/60.4 MB 23.4 MB/s eta 0:00:01
#    ---------------------------------------  59.5/60.4 MB 23.7 MB/s eta 0:00:01
#    ---------------------------------------  60.3/60.4 MB 23.8 MB/s eta 0:00:01
#    ---------------------------------------- 60.4/60.4 MB 21.6 MB/s  0:00:02
# Downloading gradio_client-1.13.1-py3-none-any.whl (325 kB)
# Downloading aiofiles-24.1.0-py3-none-any.whl (15 kB)
# Downloading audioop_lts-0.2.2-cp313-abi3-win_amd64.whl (30 kB)
# Downloading fastapi-0.117.1-py3-none-any.whl (95 kB)
# Downloading groovy-0.1.2-py3-none-any.whl (14 kB)
# Downloading huggingface_hub-0.35.0-py3-none-any.whl (563 kB)
#    ---------------------------------------- 0.0/563.4 kB ? eta -:--:--
#    ---------------------------------------- 563.4/563.4 kB 11.7 MB/s  0:00:00
# Downloading orjson-3.11.3-cp313-cp313-win_amd64.whl (131 kB)
# Downloading safehttpx-0.1.6-py3-none-any.whl (8.7 kB)
# Downloading semantic_version-2.10.0-py2.py3-none-any.whl (15 kB)
# Downloading starlette-0.48.0-py3-none-any.whl (73 kB)
# Downloading typer-0.19.1-py3-none-any.whl (46 kB)
# Downloading websockets-15.0.1-cp313-cp313-win_amd64.whl (176 kB)
# Downloading Brotli-1.1.0-cp313-cp313-win_amd64.whl (358 kB)
# Downloading python_multipart-0.0.20-py3-none-any.whl (24 kB)
# Downloading ruff-0.13.1-py3-none-win_amd64.whl (13.3 MB)
#    ---------------------------------------- 0.0/13.3 MB ? eta -:--:--
#    ------------------ --------------------- 6.0/13.3 MB 28.9 MB/s eta 0:00:01
#    ----------------------------------- ---- 11.8/13.3 MB 28.3 MB/s eta 0:00:01
#    ---------------------------------------- 13.3/13.3 MB 25.3 MB/s  0:00:00
# Downloading uvicorn-0.36.0-py3-none-any.whl (67 kB)
# Downloading ffmpy-0.6.1-py3-none-any.whl (5.5 kB)
# Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Installing collected packages: pydub, brotli, websockets, semantic-version, ruff, python-multipart, orjson, groovy, ffmpy, audioop-lts, aiofiles, uvicorn, starlette, huggingface-hub, typer, safehttpx, gradio-client, fastapi, gradio
#
#    ----------------------------------------  0/19 [pydub]
#   Attempting uninstall: brotli
#    ----------------------------------------  0/19 [pydub]
#     Found existing installation: Brotli 1.0.9
#    ----------------------------------------  0/19 [pydub]
#     Uninstalling Brotli-1.0.9:
#    ----------------------------------------  0/19 [pydub]
#    -- -------------------------------------  1/19 [brotli]
#    -- -------------------------------------  1/19 [brotli]
#    -- -------------------------------------  1/19 [brotli]
#    -- -------------------------------------  1/19 [brotli]
#    -- -------------------------------------  1/19 [brotli]
#    -- -------------------------------------  1/19 [brotli]
#    -- -------------------------------------  1/19 [brotli]
#    -- -------------------------------------  1/19 [brotli]
#    -- -------------------------------------  1/19 [brotli]
#    -- -------------------------------------  1/19 [brotli]
#    -- -------------------------------------  1/19 [brotli]
#    -- -------------------------------------  1/19 [brotli]
#    -- -------------------------------------  1/19 [brotli]
#    -- -------------------------------------  1/19 [brotli]
#    -- -------------------------------------  1/19 [brotli]
#    -- -------------------------------------  1/19 [brotli]
#    -- -------------------------------------  1/19 [brotli]
#    -- -------------------------------------  1/19 [brotli]
#    -- -------------------------------------  1/19 [brotli]
#    -- -------------------------------------  1/19 [brotli]
#    -- -------------------------------------  1/19 [brotli]
#    -- -------------------------------------  1/19 [brotli]
#    -- -------------------------------------  1/19 [brotli]
#    -- -------------------------------------  1/19 [brotli]
#    -- -------------------------------------  1/19 [brotli]
#    -- -------------------------------------  1/19 [brotli]
#    -- -------------------------------------  1/19 [brotli]
#    -- -------------------------------------  1/19 [brotli]
#    -- -------------------------------------  1/19 [brotli]
#    -- -------------------------------------  1/19 [brotli]
#    -- -------------------------------------  1/19 [brotli]
#    -- -------------------------------------  1/19 [brotli]
#    -- -------------------------------------  1/19 [brotli]
#    -- -------------------------------------  1/19 [brotli]
#    -- -------------------------------------  1/19 [brotli]
#    -- -------------------------------------  1/19 [brotli]
#    -- -------------------------------------  1/19 [brotli]
#    -- -------------------------------------  1/19 [brotli]
#    -- -------------------------------------  1/19 [brotli]
#    -- -------------------------------------  1/19 [brotli]
#    -- -------------------------------------  1/19 [brotli]
#    -- -------------------------------------  1/19 [brotli]
#    -- -------------------------------------  1/19 [brotli]
#    -- -------------------------------------  1/19 [brotli]
#    -- -------------------------------------  1/19 [brotli]
#    -- -------------------------------------  1/19 [brotli]
#    -- -------------------------------------  1/19 [brotli]
#    -- -------------------------------------  1/19 [brotli]
#    -- -------------------------------------  1/19 [brotli]
#    -- -------------------------------------  1/19 [brotli]
#    -- -------------------------------------  1/19 [brotli]
#    -- -------------------------------------  1/19 [brotli]
#    -- -------------------------------------  1/19 [brotli]
#    -- -------------------------------------  1/19 [brotli]
#    -- -------------------------------------  1/19 [brotli]
#    -- -------------------------------------  1/19 [brotli]
#    -- -------------------------------------  1/19 [brotli]
#    -- -------------------------------------  1/19 [brotli]
#    -- -------------------------------------  1/19 [brotli]
#    -- -------------------------------------  1/19 [brotli]
#    -- -------------------------------------  1/19 [brotli]
#    -- -------------------------------------  1/19 [brotli]
#    -- -------------------------------------  1/19 [brotli]
#    -- -------------------------------------  1/19 [brotli]
#    -- -------------------------------------  1/19 [brotli]
#    -- -------------------------------------  1/19 [brotli]
#    -- -------------------------------------  1/19 [brotli]
#    -- -------------------------------------  1/19 [brotli]
#    -- -------------------------------------  1/19 [brotli]
#    -- -------------------------------------  1/19 [brotli]
#    -- -------------------------------------  1/19 [brotli]
#    -- -------------------------------------  1/19 [brotli]
#    -- -------------------------------------  1/19 [brotli]
#    -- -------------------------------------  1/19 [brotli]
#       Successfully uninstalled Brotli-1.0.9
#    -- -------------------------------------  1/19 [brotli]
#    ---- -----------------------------------  2/19 [websockets]
#    ---- -----------------------------------  2/19 [websockets]
#    ---- -----------------------------------  2/19 [websockets]
#    ---- -----------------------------------  2/19 [websockets]
#    ------ ---------------------------------  3/19 [semantic-version]
#    -------- -------------------------------  4/19 [ruff]
#    -------- -------------------------------  4/19 [ruff]
#    -------- -------------------------------  4/19 [ruff]
#    -------- -------------------------------  4/19 [ruff]
#    ---------- -----------------------------  5/19 [python-multipart]
#    -------------- -------------------------  7/19 [groovy]
#    ------------------ ---------------------  9/19 [audioop-lts]
#    ----------------------- ---------------- 11/19 [uvicorn]
#    ----------------------- ---------------- 11/19 [uvicorn]
#    ----------------------- ---------------- 11/19 [uvicorn]
#    ------------------------- -------------- 12/19 [starlette]
#    ------------------------- -------------- 12/19 [starlette]
#    ------------------------- -------------- 12/19 [starlette]
#    ------------------------- -------------- 12/19 [starlette]
#    --------------------------- ------------ 13/19 [huggingface-hub]
#    --------------------------- ------------ 13/19 [huggingface-hub]
#    --------------------------- ------------ 13/19 [huggingface-hub]
#    --------------------------- ------------ 13/19 [huggingface-hub]
#    --------------------------- ------------ 13/19 [huggingface-hub]
#    --------------------------- ------------ 13/19 [huggingface-hub]
#    --------------------------- ------------ 13/19 [huggingface-hub]
#    --------------------------- ------------ 13/19 [huggingface-hub]
#    --------------------------- ------------ 13/19 [huggingface-hub]
#    --------------------------- ------------ 13/19 [huggingface-hub]
#    --------------------------- ------------ 13/19 [huggingface-hub]
#    --------------------------- ------------ 13/19 [huggingface-hub]
#    --------------------------- ------------ 13/19 [huggingface-hub]
#   Attempting uninstall: typer
#    --------------------------- ------------ 13/19 [huggingface-hub]
#    ----------------------------- ---------- 14/19 [typer]
#     Found existing installation: typer 0.9.0
#    ----------------------------- ---------- 14/19 [typer]
#     Uninstalling typer-0.9.0:
#    ----------------------------- ---------- 14/19 [typer]
#       Successfully uninstalled typer-0.9.0
#    ----------------------------- ---------- 14/19 [typer]
#    ----------------------------- ---------- 14/19 [typer]
#    ----------------------------- ---------- 14/19 [typer]
#    --------------------------------- ------ 16/19 [gradio-client]
#    --------------------------------- ------ 16/19 [gradio-client]
#    ----------------------------------- ---- 17/19 [fastapi]
#    ----------------------------------- ---- 17/19 [fastapi]
#    ----------------------------------- ---- 17/19 [fastapi]
#    ----------------------------------- ---- 17/19 [fastapi]
#    ------------------------------------- -- 18/19 [gradio]
#    ------------------------------------- -- 18/19 [gradio]
#    ------------------------------------- -- 18/19 [gradio]
#    ------------------------------------- -- 18/19 [gradio]
#    ------------------------------------- -- 18/19 [gradio]
#    ------------------------------------- -- 18/19 [gradio]
#    ------------------------------------- -- 18/19 [gradio]
#    ------------------------------------- -- 18/19 [gradio]
#    ------------------------------------- -- 18/19 [gradio]
#    ------------------------------------- -- 18/19 [gradio]
#    ------------------------------------- -- 18/19 [gradio]
#    ------------------------------------- -- 18/19 [gradio]
#    ------------------------------------- -- 18/19 [gradio]
#    ------------------------------------- -- 18/19 [gradio]
#    ------------------------------------- -- 18/19 [gradio]
#    ------------------------------------- -- 18/19 [gradio]
#    ------------------------------------- -- 18/19 [gradio]
#    ------------------------------------- -- 18/19 [gradio]
#    ------------------------------------- -- 18/19 [gradio]
#    ------------------------------------- -- 18/19 [gradio]
#    ------------------------------------- -- 18/19 [gradio]
#    ------------------------------------- -- 18/19 [gradio]
#    ------------------------------------- -- 18/19 [gradio]
#    ------------------------------------- -- 18/19 [gradio]
#    ------------------------------------- -- 18/19 [gradio]
#    ------------------------------------- -- 18/19 [gradio]
#    ------------------------------------- -- 18/19 [gradio]
#    ------------------------------------- -- 18/19 [gradio]
#    ------------------------------------- -- 18/19 [gradio]
#    ------------------------------------- -- 18/19 [gradio]
#    ------------------------------------- -- 18/19 [gradio]
#    ------------------------------------- -- 18/19 [gradio]
#    ------------------------------------- -- 18/19 [gradio]
#    ------------------------------------- -- 18/19 [gradio]
#    ------------------------------------- -- 18/19 [gradio]
#    ------------------------------------- -- 18/19 [gradio]
#    ------------------------------------- -- 18/19 [gradio]
#    ------------------------------------- -- 18/19 [gradio]
#    ------------------------------------- -- 18/19 [gradio]
#    ------------------------------------- -- 18/19 [gradio]
#    ------------------------------------- -- 18/19 [gradio]
#    ------------------------------------- -- 18/19 [gradio]
#    ------------------------------------- -- 18/19 [gradio]
#    ------------------------------------- -- 18/19 [gradio]
#    ------------------------------------- -- 18/19 [gradio]
#    ------------------------------------- -- 18/19 [gradio]
#    ------------------------------------- -- 18/19 [gradio]
#    ------------------------------------- -- 18/19 [gradio]
#    ------------------------------------- -- 18/19 [gradio]
#    ------------------------------------- -- 18/19 [gradio]
#    ------------------------------------- -- 18/19 [gradio]
#    ------------------------------------- -- 18/19 [gradio]
#    ------------------------------------- -- 18/19 [gradio]
#    ------------------------------------- -- 18/19 [gradio]
#    ------------------------------------- -- 18/19 [gradio]
#    ------------------------------------- -- 18/19 [gradio]
#    ------------------------------------- -- 18/19 [gradio]
#    ------------------------------------- -- 18/19 [gradio]
#    ------------------------------------- -- 18/19 [gradio]
#    ------------------------------------- -- 18/19 [gradio]
#    ------------------------------------- -- 18/19 [gradio]
#    ------------------------------------- -- 18/19 [gradio]
#    ------------------------------------- -- 18/19 [gradio]
#    ------------------------------------- -- 18/19 [gradio]
#    ------------------------------------- -- 18/19 [gradio]
#    ------------------------------------- -- 18/19 [gradio]
#    ------------------------------------- -- 18/19 [gradio]
#    ------------------------------------- -- 18/19 [gradio]
#    ------------------------------------- -- 18/19 [gradio]
#    ------------------------------------- -- 18/19 [gradio]
#    ------------------------------------- -- 18/19 [gradio]
#    ------------------------------------- -- 18/19 [gradio]
#    ------------------------------------- -- 18/19 [gradio]
#    ------------------------------------- -- 18/19 [gradio]
#    ------------------------------------- -- 18/19 [gradio]
#    ------------------------------------- -- 18/19 [gradio]
#    ------------------------------------- -- 18/19 [gradio]
#    ------------------------------------- -- 18/19 [gradio]
#    ------------------------------------- -- 18/19 [gradio]
#    ------------------------------------- -- 18/19 [gradio]
#    ------------------------------------- -- 18/19 [gradio]
#    ------------------------------------- -- 18/19 [gradio]
#    ------------------------------------- -- 18/19 [gradio]
#    ------------------------------------- -- 18/19 [gradio]
#    ------------------------------------- -- 18/19 [gradio]
#    ------------------------------------- -- 18/19 [gradio]
#    ------------------------------------- -- 18/19 [gradio]
#    ---------------------------------------- 19/19 [gradio]
#
# Successfully installed aiofiles-24.1.0 audioop-lts-0.2.2 brotli-1.1.0 fastapi-0.117.1 ffmpy-0.6.1 gradio-5.46.1 gradio-client-1.13.1 groovy-0.1.2 huggingface-hub-0.35.0 orjson-3.11.3 pydub-0.25.1 python-multipart-0.0.20 ruff-0.13.1 safehttpx-0.1.6 semantic-version-2.10.0 starlette-0.48.0 typer-0.19.1 uvicorn-0.36.0 websockets-15.0.1

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import re
import gradio as gr

# --- All the backend code from before ---

# Load the dataset
try:
    df = pd.read_csv('symbiosis_mba_unique_faq.csv')
    print("Dataset loaded successfully!")
except FileNotFoundError:
    print("Error: 'symbiosis_mba_unique_faq.csv' not found.")
    df = None

if df is not None:
    # Text Preprocessing
    def preprocess_text(text):
        text = text.lower()
        text = re.sub(r'[^\w\s]', '', text)
        return text

    df['Processed_Question'] = df['Question'].apply(preprocess_text)

    # TF-IDF Vectorization
    vectorizer = TfidfVectorizer()
    question_vectors = vectorizer.fit_transform(df['Processed_Question'])

    # Chatbot Response Function
    def get_response(user_input):
        processed_user_input = preprocess_text(user_input)
        user_vector = vectorizer.transform([processed_user_input])
        similarities = cosine_similarity(user_vector, question_vectors)
        most_similar_index = similarities.argmax()
        answer = df['Answer'].iloc[most_similar_index]
        return answer

    # --- New Frontend Code ---
    # This function is a simple wrapper for Gradio
    def chatbot_interface(message, history):
        return get_response(message)

    # Create and launch the Gradio Chat Interface
    iface = gr.ChatInterface(
        fn=chatbot_interface,
        title="SCIT College Chatbot",
        description="Ask me any questions about the Symbiosis MBA program."
    )
    iface.launch()
# Out:
# Dataset loaded successfully!
# C:\Users\Ananya Goel\anaconda3\Lib\site-packages\gradio\chat_interface.py:348: UserWarning: The 'tuples' format for chatbot messages is deprecated and will be removed in a future version of Gradio. Please set type='messages' instead, which uses openai-style 'role' and 'content' keys.
#   self.chatbot = Chatbot(
# * Running on local URL:  http://127.0.0.1:7860
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
